# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
unitTime_in_Myrs = 3.23 # Myrs
UnitDensity_in_cgs = 1.44e-21

# %%
pwd
# Out:
# '/home/pc/Desktop/N_body_2022/SPH_1/13_Jan_2022/MPI_sph/Isothermal_collapse_Aug_2022/Using_Slow_h/Anathpindika_II/Model_4/subSampling_IC/GPU_test'

# %%
jj = 36
file = h5py.File('./output_100k_Gad_Nngb_100/snap_' + str(jj).zfill(3) +'.hdf5', 'r')
#file = h5py.File('./output_100k_Gad/snap_' + str(jj).zfill(3) +'.hdf5', 'r')

# %%
tStep = 0.01 # From Gadget parameter file.
currentTime = jj * tStep * unitTime_in_Myrs
print(f'currentTime = {round(currentTime, 3)} Myrs.')
# Out:
# currentTime = 1.163 Myrs.

# %%
file.keys()
# Out:
# <KeysViewHDF5 ['Config', 'Header', 'Parameters', 'PartType0']>

# %%
file['Parameters']
# Out:
# <HDF5 group "/Parameters" (0 members)>

# %%
file['PartType0'].keys()
# Out:
# <KeysViewHDF5 ['Coordinates', 'Density', 'InternalEnergy', 'Masses', 'ParticleIDs', 'SmoothingLength', 'Velocities']>

# %%
coord = file['PartType0']['Coordinates']
coord
# Out:
# <HDF5 dataset "Coordinates": shape (200000, 3), type "<f4">

# %%
vel = file['PartType0']['Velocities']
np.sort((vel[:, 0]))
# Out:
# array([-5.017041 , -5.015106 , -4.9844127, ...,  5.017078 ,  5.073063 ,
#         5.1064277], dtype=float32)

# %%
#with open('../Testing_Auto_timestep/Outputs_0.5_m_8k_my_code/00400.pkl', 'rb') as f:
#    data = pickle.load(f)
#    r = data['pos']

#j = 320
    
#print(r.shape)
plt.figure(figsize = (8, 5))
plt.scatter(coord[:, 0], coord[:, 1], s = 0.001, color = 'black')
#plt.plot(coord[j, 0], coord[j, 1], marker = 'o', color = 'red')
#plt.scatter(r[:, 0], r[:, 1], s = 0.02, color = 'blue')

# xyrange = 0.5
# plt.xlim(-xyrange, xyrange)
# plt.ylim(-xyrange, xyrange)

plt.title(f't = {round(currentTime, 3)} Myrs')

plt.xlim(-1.2, 3.2)
plt.ylim(-1.5, 1.5)
# Out:
# (-1.5, 1.5)

# %%
plt.figure(figsize = (6, 5))
plt.scatter(coord[:, 1], coord[:, 2], s = 0.001, color = 'black')

xyrange = 1.0
plt.xlim(-xyrange, xyrange)
plt.ylim(-xyrange, xyrange)
#plt.xlim(-0.02, 0.05)
#plt.ylim(-0.02, 0.03)
plt.title(f't = {round(currentTime, 3)} Myrs');

# %%
h = np.array(file['PartType0']['SmoothingLength'])

np.min(h), np.max(h), np.median(h)
# Out:
# (0.008163381, 0.6937431, 0.090484075)

# %%
h = np.array(file['PartType0']['SmoothingLength'])

np.min(h), np.max(h), np.median(h)
# Out:
# (0.007875821, 0.74146706, 0.0781287)

# %%
rho = np.array(list(file['PartType0']['Density']))
np.sort(rho) * UnitDensity_in_cgs
# Out:
# array([1.0511292e-24, 1.0560626e-24, 1.0743935e-24, ..., 6.3726822e-19,
#        6.3842534e-19, 6.4476294e-19], dtype=float32)

# %%
rho = np.array(list(file['PartType0']['Density']))
np.sort(rho) * UnitDensity_in_cgs
# Out:
# array([5.7885805e-25, 6.0704217e-25, 6.7693086e-25, ..., 4.3878251e-19,
#        4.4138218e-19, 4.5287865e-19], dtype=float32)

# %%
np.sort(rho)
# Out:
# array([7.2995079e-04, 7.3337683e-04, 7.4610661e-04, ..., 4.4254739e+02,
#        4.4335095e+02, 4.4775204e+02], dtype=float32)

# %%
np.sort(rho)
# Out:
# array([4.0198475e-04, 4.2155708e-04, 4.7009089e-04, ..., 3.0471008e+02,
#        3.0651541e+02, 3.1449905e+02], dtype=float32)

# %%
u = file['PartType0']['InternalEnergy']
min(u), max(u), np.median(u)

# %%
m = np.array(file['PartType0']['Masses'])
np.sort(m)

# %%
v = file['PartType0']['Velocities']
v

# %%
ids = file['PartType0']['ParticleIDs']
ids

# %%
len(np.unique(list(ids)))
